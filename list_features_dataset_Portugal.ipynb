# %% [markdown]
# # List of features dataset allfeat_portugal
#
# This short file contains the list of all the features in the dataset allfeat_portugal.csv, and the number of missing values for each feature.

# %%
import pandas as pd
pd.set_option('display.max_rows', 200)
pd.set_option('display.max_columns', 50)

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\CLARA\\Documents\\WSBCodingSchool\\FinalProject'

# %%
portugal_all = pd.read_csv('./data/pcsv/allfeat_portugal.csv')

# %%
portugal_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2691980 entries, 0 to 2691979
# Data columns (total 20 columns):
#  #   Column            Dtype
# ---  ------            -----
#  0   Unnamed: 0        int64
#  1   centroid_alt      int64
#  2   centroid_lat      float64
#  3   centroid_lon      float64
#  4   date              object
#  5   max_T21           float64
#  6   tile_id           int64
#  7   avg_NDVI          float64
#  8   soil_moisture_am  float64
#  9   soil_moisture_pm  float64
#  10  tavg              float64
#  11  tmin              float64
#  12  tmax              float64
#  13  prcp              float64
#  14  snow              float64
#  15  wdir              float64
#  16  wspd              float64
#  17  wpgt              float64
#  18  pres              float64
#  19  tsun              float64
# dtypes: float64(16), int64(3), object(1)
# memory usage: 410.8+ MB

# %%
portugal_all.isna().sum()
# Out:
# Unnamed: 0                0
# centroid_alt              0
# centroid_lat              0
# centroid_lon              0
# date                      0
# max_T21                   0
# tile_id                   0
# avg_NDVI            2521975
# soil_moisture_am      80085
# soil_moisture_pm      80085
# tavg                 156574
# tmin                 184529
# tmax                 258872
# prcp                 967680
# snow                2682359
# wdir                 271287
# wspd                 267234
# wpgt                1168802
# pres                 268889
# tsun                2691980
# dtype: int64
